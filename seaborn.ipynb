# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=sns.load_dataset('tips')

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.lineplot(x='total_bill',y='tip',hue='sex',data=data)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(x='total_bill',y='tip',hue='sex',data=data,style='sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(x='total_bill',y='tip',style='time',data=data,legend='full')
plt.show()

# %%
sns.scatterplot(x='total_bill',y='tip',style='time',data=data,legend='full')
plt.show()

# %%
sns.scatterplot(x='total_bill',y='tip',style='sex',data=data,size='size')
plt.show()

# %%
sns.scatterplot(x='total_bill',y='tip',hue='sex',data=data,palette=['red','blue'])
plt.show()

# %%
sns.scatterplot(x='total_bill',y='tip',hue='sex',data=data,palette=['red','blue'],hue_order=['Female','Male'])
plt.show()

# %%
sns.scatterplot(x='total_bill',y='tip',data=data,hue='sex',marker='s')
plt.show()

# %%
sns.barplot(x='day',y='total_bill',data=data)
plt.show()

# %%
sns.barplot(x='day',y='total_bill',data=data,hue='sex')
plt.show()

# %%
sns.barplot(x='day',y='total_bill',data=data,hue='sex',order=['Sun','Thur','Fri','Sat'])
plt.show()

# %%
sns.barplot(x='day',y='total_bill',data=data,hue='sex',palette=['red','green'])
plt.show()

# %%
sns.barplot(x='day',y='total_bill',data=data,hue='sex',errcolor='.8')
plt.show()
# Out:
# /tmp/ipython-input-487040927.py:1: FutureWarning:
#
# The `errcolor` parameter is deprecated. And will be removed in v0.15.0. Pass `err_kws={'color': '.8'}` instead.
#
#   sns.barplot(x='day',y='total_bill',data=data,hue='sex',errcolor='.8')

# %%
sns.histplot(x='total_bill',data=data,hue='sex')
plt.show()

# %%
sns.histplot(x='total_bill',data=data,hue='sex',stat='probability')
plt.show()

# %%
sns.histplot(x='total_bill',data=data,hue='sex',bins=10)
plt.show()

# %%
sns.histplot(x='total_bill',data=data,hue='sex',kde=True)
plt.show()

# %%
sns.histplot(x='total_bill',data=data,hue='sex',kde=True,fill=False)
plt.show()

# %%
sns.histplot(x='total_bill',data=data,hue='sex',element='poly')
plt.show()

# %%
sns.histplot(x='total_bill',data=data,hue='sex',multiple='stack')
plt.show()

# %%
sns.histplot(x='total_bill',data=data,hue='sex',multiple='dodge')
plt.show()

# %%
sns.histplot(x='total_bill',data=data,hue='sex',multiple='fill')
plt.show()

# %%
sns.histplot(x='total_bill',data=data,hue='sex',fill=False)
plt.show()

# %%
import pandas as pd
numeric_tips=data

# %%
correlation_matrix =numeric_tips.corr(numeric_only=True)
correlation_matrix
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
plt.figure(figsize=(8,6))
sns.heatmap(correlation_matrix ,annot=True, cmap='coolwarm', fmt='.2f', linewidth=0.5, cbar=True)
plt.show()

# %%
sns.pairplot(data)
plt.suptitle('Pairplot of tip dataset')
plt.show()

# %%
sns.pairplot(data,hue='sex',markers='*')
plt.suptitle("pairplot of tip dataset",y=1.02)
plt.show()

# %%
sns.jointplot(x='total_bill',y='tip',data=data,kind='reg')
plt.suptitle('join plot of Total Bill vs Tip')
plt.show()
